# %% [markdown]
# # Assignment 1 Setup Index

# %%
import os
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re
import json
import numpy as np
import math
from elasticsearch7 import Elasticsearch
from tqdm import tqdm

# %%
# Path to the directory containing files
DIRECTORY_PATH = 'ap89_collection/'
QUERY_PATH = 'AP_DATA/query_desc.51-100.short.txt'
INDEX_NAME = 'ap89_collection_v1'
STOP_WORDS_PATH = 'AP_DATA/stoplist.txt'
DEFAULT_HEADER = {'Content-Type': 'application/json'}
ES_URL = "http://localhost:9200/"

es = Elasticsearch(ES_URL)

# %% [markdown]
# # Task 2 : Document Indexing

# %% [markdown]
# Create an index of the downloaded corpus. The documents are found within the ap89_collection folder in the data .zip file. You will need to write a program to parse the documents and send them to your elasticsearch instance.
#
# The corpus files are in a standard format used by TREC. Each file contains multiple documents. The format is similar to XML, but standard XML and HTML parsers will not work correctly. Instead, read the file one line at a time with the following rules:
#
# 1. Each document begins with a line containing <DOC> and ends with a line containing </DOC>.
# 2. The first several lines of a document’s record contain various metadata. You should read the <DOCNO> field and use it as the ID of the document.
# 3. The document contents are between lines containing <TEXT> and </TEXT>.
# 4. All other file contents can be ignored.
#
# Use elasticsearch API to retrieve values like term frequency and term positions within a document. You will need such values to score documents using the retrieval models listed below.

# %%
import os
import pandas as pd
import re


data = []

for filename in os.listdir(DIRECTORY_PATH):
    file_path = os.path.join(DIRECTORY_PATH, filename)

    with open(file_path, 'r', encoding='ISO-8859-1', errors='ignore') as file:
        content = file.read()

    # Use regular expression to extract each document
    docs = re.findall(r'<DOC>.*?</DOC>', content, flags=re.DOTALL)

    # Extract metadata and text for each document
    for doc in docs:
        docno_match = re.search(r'<DOCNO>(.*?)</DOCNO>', doc)
        fileid_match = re.search(r'<FILEID>(.*?)</FILEID>', doc)
        first_match = re.search(r'<FIRST>(.*?)</FIRST>', doc)
        second_match = re.search(r'<SECOND>(.*?)</SECOND>', doc)
        head_matches = re.findall(r'<HEAD>(.*?)</HEAD>', doc)
        byline_match = re.search(r'<BYLINE>(.*?)</BYLINE>', doc)
        dateline_match = re.search(r'<DATELINE>(.*?)</DATELINE>', doc)
        text_match = re.search(r'<TEXT>(.*?)</TEXT>', doc, flags=re.DOTALL)

        # Create a dictionary for each document
        doc_data = {
            'DOCNO': docno_match.group(1) if docno_match else None,
            'FILEID': fileid_match.group(1) if fileid_match else None,
            'FIRST': first_match.group(1) if first_match else None,
            'SECOND': second_match.group(1) if second_match else None,
            'HEAD': head_matches if head_matches else None,
            'BYLINE': byline_match.group(1) if byline_match else None,
            'DATELINE': dateline_match.group(1) if dateline_match else None,
            'TEXT': text_match.group(1) if text_match else None
        }
        data.append(doc_data)


df = pd.DataFrame(data)
df
# Out:
#                  DOCNO                  FILEID  \
# 0       AP891220-0001   AP-NR-12-20-89 2343EST
# 1       AP891220-0002   AP-NR-12-20-89 0031EST
# 2       AP891220-0003   AP-NR-12-20-89 0038EST
# 3       AP891220-0004   AP-NR-12-20-89 0039EST
# 4       AP891220-0005   AP-NR-12-20-89 0039EST
# ...                ...                     ...
# 84674   AP890726-0308   AP-NR-07-26-89 1933EDT
# 84675   AP890726-0309   AP-NR-07-26-89 1937EDT
# 84676   AP890726-0310   AP-NR-07-26-89 2131EDT
# 84677   AP890726-0311   AP-NR-07-26-89 2223EDT
# 84678   AP890726-0312   AP-NR-07-26-89 2224EDT
#
#                                                    FIRST  \
# 0                u i BC-Panama-Resistance     12-20 0723
# 1                    r a AM-RollingStones     12-20 0372
# 2             r a PM-Christmas-Jesus'KinI     12-20 1240
# 3                r i PM-SAfrica-CoupTrial     12-20 0176
# 4                  r a PM-RobinsonProfile     12-20 0558
# ...                                                  ...
# 84674  u f AM-Psychiatrist-InsiderTrading     07-26 0312
# 84675  u f AM-ComputerVirus 2ndLd-Writethru f0258 07-...
# 84676                u f AM-Japan-Markets     07-26 0275
# 84677  r f AM-InteriorBill 3rdLd-Writethru f0329 07-2...
# 84678             r f BC-Ashland-7-Eleven     07-26 0159
#
#                                                 SECOND  \
# 0                            BC-Panama-Resistance,0746
# 1                               AM-Rolling Stones,0385
# 2                       PM-Christmas-Jesus' Kin I,1277
# 3                           PM-SAfrica-Coup Trial,0178
# 4                             PM-Robinson Profile,0576
# ...                                                ...
# 84674             AM-Psychiatrist-Insider Trading,0322
# 84675  AM-Computer Virus, 2nd Ld-Writethru, f0258,0664
# 84676                            AM-Japan-Markets,0285
# 84677   AM-Interior Bill, 3rd Ld-Writethru, f0329,0762
# 84678                         BC-Ashland-7-Eleven,0168
#
#                                                     HEAD  \
# 0      [Defense Forces, Noriega Resist; Loyalty Remai...
# 1      [Stones Pay Per View Concert Tops North Americ...
# 2      [Part I: Jesus Descended From Checkered Ancest...
# 3      [Leader Of Failed Homeland Coup Gets 18-Year P...
# 4      [Savannah Leaders Praise Slain Alderman, Eds: ...
# ...                                                  ...
# 84674  [Psychiatrist Charged With Using Inside Inform...
# 84675  [Grand Jury Indicts Cornell Student on Compute...
# 84676  [Dollar Falls, Stock Prices Move For New High ...
# 84677  [Senate Mulls Spending Bill Easing Ocean Drill...
# 84678      [Ashland Division Buys 66 Convenience Stores]
#
#                      BYLINE                          DATELINE  \
# 0        By ELOY O. AGUILAR         PANAMA CITY, Panama (AP)
# 1            By HENRY STERN         ATLANTIC CITY, N.J. (AP)
# 2      By GEORGE W. CORNELL                              None
# 3                      None  JOHANNESBURG, South Africa (AP)
# 4       By LAURAN NEERGAARD               SAVANNAH, Ga. (AP)
# ...                     ...                               ...
# 84674        By VERA HALLER                    NEW YORK (AP)
# 84675       By JAMES ROWLEY                  WASHINGTON (AP)
# 84676                  None                       TOKYO (AP)
# 84677          By ALAN FRAM                  WASHINGTON (AP)
# 84678                  None                ASHLAND, Ky. (AP)
#
#                                                     TEXT
# 0      \n   Instead of collapsing when the United\nSt...
# 1      \n   The Rolling Stones capped the\nnext-to-la...
# 2      \n   This first installment of a three-part Ch...
# 3      \n   A soldier who led a failed\ncoup attempt ...
# 4      \n   Robert Robinson, the alderman and lawyer\...
# ...                                                  ...
# 84674  \n   A psychiatrist was indicted Wednesday on\...
# 84675  \n   A Cornell University graduate student was...
# 84676  \n   The U.S. dollar fell in early trading aga...
# 84677  \n   The Senate approved legislation on Wednes...
# 84678  \n   SuperAmerica, the retail gasoline marketi...
#
# [84679 rows x 8 columns]

# %%
import string
from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)

# Open stopwords file
with open(STOP_WORDS_PATH, 'r') as file:
    stoplist = file.read().splitlines()

# Preprocess the text
def preprocess_text(text, stoplist):
    # Remove punctuation from text
    text = re.sub(r'[^\w\s]', ' ', text)
    tokens = word_tokenize(text)
    tokens = [token.strip().lower() for token in tokens]
    tokens = [token for token in tokens if token not in stoplist]
    stemmer = PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]
    text = ' '.join(tokens)
    return text
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
def token_lengths(text):
    tokens = word_tokenize(text)
    return len(tokens)

df['PROCESSED_TEXT'] = df['TEXT'].parallel_apply(preprocess_text, args=(stoplist,))
df['DOCNO'] = df['DOCNO'].str.strip()
df.head()
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=8468), Label(value='0 / 8468'))), …
#            DOCNO                  FILEID  \
# 0  AP891220-0001  AP-NR-12-20-89 2343EST
# 1  AP891220-0002  AP-NR-12-20-89 0031EST
# 2  AP891220-0003  AP-NR-12-20-89 0038EST
# 3  AP891220-0004  AP-NR-12-20-89 0039EST
# 4  AP891220-0005  AP-NR-12-20-89 0039EST
#
#                                         FIRST                          SECOND  \
# 0     u i BC-Panama-Resistance     12-20 0723       BC-Panama-Resistance,0746
# 1         r a AM-RollingStones     12-20 0372          AM-Rolling Stones,0385
# 2  r a PM-Christmas-Jesus'KinI     12-20 1240  PM-Christmas-Jesus' Kin I,1277
# 3     r i PM-SAfrica-CoupTrial     12-20 0176      PM-SAfrica-Coup Trial,0178
# 4       r a PM-RobinsonProfile     12-20 0558        PM-Robinson Profile,0576
#
#                                                 HEAD                BYLINE  \
# 0  [Defense Forces, Noriega Resist; Loyalty Remai...    By ELOY O. AGUILAR
# 1  [Stones Pay Per View Concert Tops North Americ...        By HENRY STERN
# 2  [Part I: Jesus Descended From Checkered Ancest...  By GEORGE W. CORNELL
# 3  [Leader Of Failed Homeland Coup Gets 18-Year P...                  None
# 4  [Savannah Leaders Praise Slain Alderman, Eds: ...   By LAURAN NEERGAARD
#
#                            DATELINE  \
# 0         PANAMA CITY, Panama (AP)
# 1         ATLANTIC CITY, N.J. (AP)
# 2                              None
# 3  JOHANNESBURG, South Africa (AP)
# 4               SAVANNAH, Ga. (AP)
#
#                                                 TEXT  \
# 0  \n   Instead of collapsing when the United\nSt...
# 1  \n   The Rolling Stones capped the\nnext-to-la...
# 2  \n   This first installment of a three-part Ch...
# 3  \n   A soldier who led a failed\ncoup attempt ...
# 4  \n   Robert Robinson, the alderman and lawyer\...
#
#                                       PROCESSED_TEXT
# 0  collaps unit state threw militari gen manuel a...
# 1  roll stone cap show 32 citi north american tou...
# 2  instal three part christma seri rel jesu deal ...
# 3  soldier led fail coup attempt south africa s n...
# 4  robert robinson alderman lawyer assassin mail ...

# %%
es.ping()
# Out:
# True

# %%
configurations = {
    "settings" : {
        "number_of_shards": 1,
        "number_of_replicas": 1,
        "analysis": {
            "filter": {
                "english_stop": {
                    "type": "stop",
                    "stopwords_path": "my_stoplist.txt"
                }
            },
            "analyzer": {
                "stopped": {
                    "type": "custom",
                    "tokenizer": "standard",
                    "filter": [
                        "lowercase",
                        "english_stop"
                    ]
                }
            }
      }
    },
    "mappings": {
        "properties": {
            "content": {
                "type": "text",
                "fielddata": True,
                "analyzer": "stopped",
                "index_options": "positions"
            }
        }
    }
}

es.indices.create(index=INDEX_NAME, body=configurations)

def add_data(id, text):
    es.index(index=INDEX_NAME, id=id, document={'content': text})

# Loop through all documents
for index, row in df.iterrows():
    # Add document to the index
    add_data(row['DOCNO'], row['PROCESSED_TEXT'])
# Out:
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_58859/1085697077.py:36: DeprecationWarning: The 'body' parameter is deprecated for the 'create' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   es.indices.create(index=INDEX_NAME, body=configurations)

# %%
# es.indices.delete(index=INDEX_NAME)
# Out:
# {'acknowledged': True}

# %% [markdown]
# # Task3: Query execution
# Write a program to run the queries in the file query_desc.51-100.short.txt, included in the data .zip file. You should run all queries (omitting the leading number) using each of the retrieval models listed below, and output the top 1000 results for each query to an output file. If a particular query has fewer than 1000 documents with a nonzero matching score, then just list whichever documents have nonzero scores.
#
# You should write precisely one output file per retrieval model. Each line of an output file should specify one retrieved document, in the following format:

# %%
def read_queries(path):
    queries = {}
    with open(QUERY_PATH, 'r') as file:
        content = file.readlines()
        # Extract query id and query text
        for line in content:
            query_id, query_text = line.split('.', 1)
            queries[query_id] = {
                'original_query': query_text,
                'processed_query': word_tokenize(preprocess_text(query_text, stoplist))
            }
    return queries

queries = read_queries(QUERY_PATH)
queries
# Out:
# {'85': {'original_query': '   Document will discuss allegations, or measures being taken against, corrupt public officials of any governmental jurisdiction worldwide.   \n',
#   'processed_query': ['alleg', 'corrupt', 'public', 'offici']},
#  '59': {'original_query': '   Document will report a type of weather event which has directly caused at least one fatality in some location.   \n',
#   'processed_query': ['weather', 'least', 'fatal', 'locat']},
#  '56': {'original_query': '   Document will include a prediction about the prime lending rate, or will report an actual prime rate move.   \n',
#   'processed_query': ['prime', 'lend', 'rate', 'prime', 'rate']},
#  '71': {'original_query': '   Document will report incursions by land, air, or water into the border area of one country by military forces of a second country or a guerrilla group based in a second country.   \n',
#   'processed_query': ['incurs',
#    'border',
#    'area',
#    'militari',
#    'forc',
#    'second',
#    'guerrilla',
#    'second']},
#  '64': {'original_query': '   Document will report an event or result of politically motivated hostage-taking.  \n',
#   'processed_query': ['result', 'polit', 'hostag', 'take']},
#  '62': {'original_query': "   Document will report a military coup d'etat, either attempted or successful, in any country.   \n",
#   'processed_query': ['militari', 'coup', 'd', 'etat', 'attempt']},
#  '93': {'original_query': '   Document must describe or identify supporters of the National Rifle Association (NRA), or its assets.  \n',
#   'processed_query': ['support', 'nation', 'rifl', 'associ', 'nra']},
#  '99': {'original_query': '   Document will identify a development in the Iran-Contra Affair.   \n',
#   'processed_query': ['develop', 'iran', 'contra', 'affair']},
#  '58': {'original_query': '   Document will predict or anticipate a rail strike or report an ongoing rail  strike.     \n',
#   'processed_query': ['rail', 'strike', 'ongo', 'rail', 'strike']},
#  '77': {'original_query': '   Document will report a poaching method used against a certain type of wildlife.  \n',
#   'processed_query': ['poach', 'method', 'wildlif']},
#  '54': {'original_query': '   Document will cite the signing of a contract or preliminary agreement, or the making of a tentative reservation, to launch a commercial satellite.   \n',
#   'processed_query': ['contract',
#    'agreement',
#    'reserv',
#    'launch',
#    'commerci',
#    'satellit']},
#  '87': {'original_query': '   Document will report on current criminal actions against officers of a failed U.S. financial institution.   \n',
#   'processed_query': ['current', 'offic', 'fail', 'u', 's', 'institut']},
#  '94': {'original_query': '   Document must identify a crime perpetrated with the aid of a computer.   \n',
#   'processed_query': ['crime', 'aid', 'comput']},
#  '100': {'original_query': '  Document will identify efforts by the non-communist, industrialized states to regulate the transfer of high-tech goods or "dual-use" technologies to undesirable nations.   \n',
#   'processed_query': ['non',
#    'communist',
#    'state',
#    'transfer',
#    'high',
#    'tech',
#    'good',
#    'technolog',
#    'nation']},
#  '89': {'original_query': '   Document must identify an existing or pending investment by an OPEC member state in any "downstream" operation.   \n',
#   'processed_query': ['invest', 'opec', 'downstream']},
#  '61': {'original_query': '   Document will discuss the role of Israel in the Iran-Contra Affair.   \n',
#   'processed_query': ['israel', 'iran', 'contra', 'affair']},
#  '95': {'original_query': '   Document must describe a computer application to crime solving.   \n',
#   'processed_query': ['comput', 'applic', 'crime']},
#  '68': {'original_query': '   Document will report actual studies, or even unsubstantiated concerns about the safety to manufacturing employees and installation workers of fine-diameter fibers used in insulation and other products.   \n',
#   'processed_query': ['concern',
#    'safeti',
#    'manufactur',
#    'worker',
#    'fine',
#    'diamet',
#    'fiber',
#    'product']},
#  '57': {'original_query': '   Document will discuss how MCI has been doing since the Bell System breakup.   \n',
#   'processed_query': ['mci', 'bell', 'system']},
#  '97': {'original_query': '   Document must identify instances of fiber optics technology actually in use.    \n',
#   'processed_query': ['fiber', 'optic', 'technolog']},
#  '98': {'original_query': '   Document must identify individuals or organizations which produce fiber optics equipment.   \n',
#   'processed_query': ['fiber', 'optic', 'equip']},
#  '60': {'original_query': '   Document will describe either one or both sides of the controversy over the use of standards of performance to determine salary levels and incentive pay as contrasted with determining pay solely on the basis of seniority or longevity on the job.   \n',
#   'processed_query': ['perform', 'salari', 'incent', 'pay', 'pay']},
#  '80': {'original_query': '   Document will identify something about the platform of a 1988 presidential  candidate.   \n',
#   'processed_query': ['1988', 'presidenti', 'candid']},
#  '63': {'original_query': '   Document will identify a machine translation system.   \n',
#   'processed_query': ['machin', 'translat', 'system']},
#  '91': {'original_query': '   Document will identify acquisition by the U.S. Army of specified advanced weapons systems.   ',
#   'processed_query': ['u', 's', 'weapon', 'system']}}

# %%
def fetch_all_document_ids(path="AP_DATA/doclist_new_0609.txt"):
    with open(path, 'r') as file:
        all_document_ids = []
        for line in file:
            all_document_ids.append(line.strip().split(' ')[2])
    return all_document_ids

def fetch_all_term_vectors(document_ids):
    document_to_vectors = {}
    document_to_length = {}
    term_document_frequency = {}
    term_total_term_frequency = {}
    vocabulary_words = set()

    def fetch_term_vectors(id_batch):

        vectors = es.mtermvectors(index=INDEX_NAME, term_statistics = True, ids=id_batch, fields='content')

        for tv in vectors['docs']:
            document_id = tv['_id']

            if 'content' not in tv['term_vectors']:
                document_to_vectors[document_id] = {}
                document_to_length[document_id] = 0
            else:
                terms = tv['term_vectors']['content']['terms']

                for term in terms:
                    term_document_frequency[term] = terms[term]['doc_freq']
                    term_total_term_frequency[term] = terms[term]['ttf']

                document_to_vectors[document_id] = terms
                document_to_length[document_id] = sum([terms[x]['term_freq'] for x in terms])
                for term in terms:
                    vocabulary_words.add(term)

    batch_size = 250
    for i in tqdm(range(0, len(document_ids), batch_size)):
        id_batch = document_ids[i:i + batch_size]
        fetch_term_vectors(id_batch)

    return document_to_vectors, document_to_length, term_document_frequency, term_total_term_frequency, vocabulary_words

all_document_ids = fetch_all_document_ids()
document_to_vectors, document_to_length, term_document_frequency, term_total_term_frequency, vocabulary_words = fetch_all_term_vectors(all_document_ids)

number_of_documents = len(all_document_ids)
average_document_length = sum([document_to_length[d] for d in all_document_ids]) / number_of_documents
total_document_length = sum([document_to_length[d] for d in all_document_ids])
vocabulary_size = len(vocabulary_words)
# Out:
# 100%|██████████| 339/339 [05:23<00:00,  1.05it/s]

# %%
def get_doc_freq(term):
    if term in term_document_frequency:
        return term_document_frequency[term]
    else:
        return 0

def get_term_freq(term, document_id):
    if document_id in document_to_vectors and term in document_to_vectors[document_id]:
        return document_to_vectors[document_id][term]['term_freq']
    else:
        return 0

def get_word_freq_in_query(term, query):
    return query.count(term)

# %% [markdown]
# ### ES built-in
# Use ES query with the API "match"{"body_text":"query keywords"}. This should be somewhat similar to BM25 scoring.

# %%
es.ping()
# Out:
# True

# %%
def es_built_in_search(queries, size=1000):
    scores = {}

    for query_id, query in queries.items():
        query = query['processed_query']

        res = es.search(index=INDEX_NAME, body={
            "query": {
                "match": {
                    "content": " ".join(query)
                }
            },
            "size": size
        })

        hits = res['hits']['hits']
        scores[query_id] = []
        for hit in hits:
            scores[query_id].append((hit['_id'], hit['_score']))

    return scores

es_built_in_search(queries)
# Out:
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_64086/2650714926.py:7: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=INDEX_NAME, body={
# {'85': [('AP890220-0143', 14.12233),
#   ('AP890108-0030', 14.116497),
#   ('AP890107-0129', 13.96368),
#   ('AP890516-0072', 13.818281),
#   ('AP890517-0182', 13.717943),
#   ('AP890125-0007', 13.654452),
#   ('AP890516-0158', 13.648869),
#   ('AP890518-0050', 13.523772),
#   ('AP890122-0062', 13.10289),
#   ('AP891111-0095', 13.092963),
#   ('AP890131-0078', 12.932965),
#   ('AP890503-0199', 12.922917),
#   ('AP890223-0032', 12.826558),
#   ('AP890819-0056', 12.751603),
#   ('AP890622-0096', 12.732622),
#   ('AP890112-0180', 12.686827),
#   ('AP891013-0120', 12.65733),
#   ('AP890522-0129', 12.646246),
#   ('AP890915-0075', 12.636365),
#   ('AP890714-0124', 7.1582613),
#   ('AP890901-0165', 7.15487),
#   ('AP890426-0134', 7.152444),
#   ('AP890319-0016', 7.151557),
#   ('AP890515-0012', 7.151557),
#   ('AP890915-0104', 7.143796),
#   ('AP890419-0186', 7.143796),
#   ('AP890414-0045', 7.143265),
#   ('AP890125-0158', 7.143265),
#   ('AP890723-0020', 7.1385665),
#   ('AP890119-0353', 7.1385665),
#   ('AP890908-0040', 7.137929),
#   ('AP890906-0081', 7.135555),
#   ('AP891108-0204', 7.135555),
#   ('AP890222-0154', 7.132821),
#   ('AP891204-0274', 7.131238),
#   ('AP890625-0003', 7.127674),
#   ('AP890426-0051', 7.1190004),
#   ('AP890824-0070', 7.117746),
#   ('AP891122-0217', 7.112547),
#   ('AP890619-0191', 7.1059294),
#   ('AP890910-0067', 7.102295),
#   ('AP891129-0204', 7.102217),
#   ('AP890513-0036', 7.101506),
#   ('AP890211-0102', 7.099488),
#   ('AP890128-0142', 7.099488),
#   ('AP890915-0228', 7.095589),
#   ('AP890325-0071', 7.0937023),
#   ('AP890912-0166', 7.0937023),
#   ('AP890308-0117', 7.0924535),
#   ('AP890511-0088', 7.0889664),
#   ('AP890919-0084', 7.087784),
#   ('AP891004-0091', 7.0873914),
#   ('AP890913-0249', 7.0850635),
#   ('AP891212-0156', 7.0850635),
#   ('AP891024-0019', 7.080076),
#   ('AP891128-0018', 7.0797586),
#   ('AP890221-0204', 7.0776606),
#   ('AP890407-0127', 7.0763087),
#   ('AP890804-0181', 7.0763087),
#   ('AP891226-0186', 7.07604),
#   ('AP890128-0012', 7.073946),
#   ('AP890914-0168', 7.073946),
#   ('AP890104-0129', 7.0694265),
#   ('AP891206-0038', 7.0694265),
#   ('AP890308-0152', 7.0689154),
#   ('AP890106-0009', 7.065819),
#   ('AP890802-0195', 7.064267),
#   ('AP890825-0069', 7.063655),
#   ('AP890825-0032', 7.062765),
#   ('AP890804-0147', 7.0558033),
#   ('AP891025-0297', 7.0511193),
#   ('AP890220-0138', 7.0511193),
#   ('AP890914-0032', 7.0511193),
#   ('AP890102-0052', 7.050879),
#   ('AP890531-0190', 7.050879),
#   ('AP891121-0095', 7.0499673),
#   ('AP890106-0049', 7.0459995),
#   ('AP890622-0144', 7.0450435),
#   ('AP890302-0026', 7.0359287),
#   ('AP890427-0191', 7.0359287),
#   ('AP890519-0266', 7.035204),
#   ('AP890828-0110', 7.031849),
#   ('AP890103-0083', 7.030884),
#   ('AP890829-0009', 7.030884),
#   ('AP890712-0041', 7.030884),
#   ('AP890728-0265', 7.0256),
#   ('AP890418-0065', 7.008384),
#   ('AP890607-0049', 6.9998198),
#   ('AP890329-0048', 6.9964),
#   ('AP890531-0218', 6.993079),
#   ('AP890601-0017', 6.993079),
#   ('AP890921-0150', 6.993079),
#   ('AP890502-0080', 6.9816723),
#   ('AP890913-0306', 6.9816723),
#   ('AP890506-0063', 6.9816723),
#   ('AP890426-0241', 6.9816723),
#   ('AP890809-0296', 6.9816723),
#   ('AP891204-0259', 6.981267),
#   ('AP890822-0191', 8.488194),
#   ('AP890918-0168', 8.488194),
#   ('AP890505-0070', 8.441271),
#   ('AP890312-0067', 8.438791),
#   ('AP890612-0030', 8.438791),
#   ('AP891216-0157', 8.423171),
#   ('AP890310-0106', 8.419409),
#   ('AP890616-0170', 8.416687),
#   ('AP891222-0085', 8.394103),
#   ('AP890315-0143', 8.381874),
#   ('AP891228-0129', 8.381046),
#   ('AP891229-0046', 8.372262),
#   ('AP890111-0021', 8.372262),
#   ('AP890919-0045', 8.364823),
#   ('AP890706-0200', 8.356543),
#   ('AP890817-0075', 8.355766),
#   ('AP891121-0038', 8.355766),
#   ('AP891014-0138', 8.349289),
#   ('AP890725-0147', 8.339418),
#   ('AP890112-0027', 8.339418),
#   ('AP890403-0122', 8.33807),
#   ('AP890720-0098', 8.333208),
#   ('AP890131-0100', 8.332516),
#   ('AP891024-0025', 8.331085),
#   ('AP891209-0044', 8.309427),
#   ('AP890128-0100', 8.277534),
#   ('AP890920-0102', 8.277534),
#   ('AP890827-0002', 8.273097),
#   ('AP890827-0003', 8.273097),
#   ('AP891222-0185', 8.273097),
#   ('AP890207-0217', 8.263238),
#   ('AP890409-0039', 8.250417),
#   ('AP890712-0204', 8.24892),
#   ('AP891204-0134', 8.23208),
#   ('AP891025-0037', 8.211111),
#   ('AP890410-0200', 8.204762),
#   ('AP890511-0235', 8.198569),
#   ('AP890905-0001', 8.198569),
#   ('AP890624-0036', 8.198023),
#   ('AP890227-0008', 8.174254),
#   ('AP891231-0033', 8.166739),
#   ('AP890927-0211', 8.157669),
#   ('AP890103-0169', 8.156374),
#   ('AP890724-0042', 8.148876),
#   ('AP890827-0020', 8.134674),
#   ('AP890106-0030', 8.134674),
#   ('AP890420-0164', 8.134674),
#   ('AP890223-0013', 8.120026),
#   ('AP890127-0025', 8.118225),
#   ('AP891024-0090', 8.104106),
#   ('AP891013-0037', 8.097515),
#   ('AP890501-0201', 8.093709),
#   ('AP890812-0099', 8.087608),
#   ('AP890923-0097', 8.056982),
#   ('AP890202-0003', 8.052449),
#   ('AP890706-0121', 8.036269),
#   ('AP890824-0039', 8.036269),
#   ('AP890126-0140', 8.030048),
#   ('AP890520-0027', 8.022031),
#   ('AP890911-0078', 8.020739),
#   ('AP890308-0102', 8.019423),
#   ('AP890922-0010', 8.019423),
#   ('AP890203-0012', 8.016838),
#   ('AP890719-0277', 8.012996),
#   ('AP890205-0019', 8.012909),
#   ('AP890906-0068', 8.004401),
#   ('AP890219-0012', 8.004302),
#   ('AP890316-0013', 7.998559),
#   ('AP890515-0104', 7.997143),
#   ('AP890406-0026', 7.992689),
#   ('AP891111-0073', 7.9786863),
#   ('AP890928-0078', 7.978325),
#   ('AP891109-0276', 7.9519806),
#   ('AP890610-0088', 7.9469347),
#   ('AP890719-0007', 7.9469347),
#   ('AP890519-0111', 7.935873),
#   ('AP891130-0227', 7.9298725),
#   ('AP890519-0018', 7.9259377),
#   ('AP891215-0175', 7.92282),
#   ('AP890405-0104', 7.92282),
#   ('AP890908-0192', 7.918849),
#   ('AP890421-0055', 7.4795732),
#   ('AP890329-0136', 7.4795732),
#   ('AP890701-0137', 7.4687824),
#   ('AP890317-0023', 7.4687824),
#   ('AP890118-0048', 7.4658337),
#   ('AP891227-0141', 7.459574),
#   ('AP890127-0070', 7.4580646),
#   ('AP890727-0126', 7.4578094),
#   ('AP890311-0132', 7.4578094),
#   ('AP890227-0268', 7.4537206),
#   ('AP890921-0202', 7.4338503),
#   ('AP890814-0122', 7.432796),
#   ('AP890809-0094', 7.432796),
#   ('AP890702-0004', 7.430917),
#   ('AP890308-0168', 7.428935),
#   ('AP890307-0015', 7.4061813),
#   ('AP890614-0068', 7.4061813),
#   ('AP890716-0093', 7.4061813),
#   ('AP891208-0063', 7.4061813),
#   ('AP891209-0012', 7.387227),
#   ('AP890727-0021', 7.3706803),
#   ('AP891221-0154', 7.366127),
#   ('AP891016-0006', 7.366127),
#   ('AP890821-0120', 7.3618865),
#   ('AP890310-0151', 7.3618865),
#   ('AP890619-0176', 7.3538275),
#   ('AP890704-0044', 7.350734),
#   ('AP890215-0093', 7.3489065),
#   ('AP890819-0094', 7.3441076),
#   ('AP891013-0104', 7.3390617),
#   ('AP891118-0043', 7.3390617),
#   ('AP890903-0056', 7.3390617),
#   ('AP891222-0124', 7.3390617),
#   ('AP890426-0177', 7.334476),
#   ('AP890307-0060', 7.328847),
#   ('AP891122-0167', 7.31979),
#   ('AP891229-0047', 7.3162684),
#   ('AP890724-0094', 7.3162684),
#   ('AP891211-0081', 7.315944),
#   ('AP890818-0039', 7.3138733),
#   ('AP890129-0084', 7.3138733),
#   ('AP890622-0134', 7.3138733),
#   ('AP890106-0012', 7.3017797),
#   ('AP891118-0023', 7.3000684),
#   ('AP890925-0075', 7.280391),
#   ('AP891228-0066', 7.2794366),
#   ('AP890506-0033', 7.2770348),
#   ('AP890719-0185', 7.269632),
#   ('AP891223-0091', 7.26515),
#   ('AP890616-0086', 7.25171),
#   ('AP890830-0246', 7.24666),
#   ('AP891108-0117', 7.2444315),
#   ('AP890221-0093', 7.242496),
#   ('AP891106-0103', 7.242496),
#   ('AP890114-0009', 7.2395835),
#   ('AP890208-0103', 7.2377877),
#   ('AP890627-0183', 7.2262588),
#   ('AP890825-0153', 7.2262588),
#   ('AP891024-0142', 7.207591),
#   ('AP890204-0001', 7.2054925),
#   ('AP890829-0248', 7.196784),
#   ('AP890615-0048', 7.196784),
#   ('AP891130-0264', 7.196784),
#   ('AP890310-0081', 7.196784),
#   ('AP891020-0080', 7.1887093),
#   ('AP890315-0314', 7.183782),
#   ('AP890101-0057', 7.1783648),
#   ('AP890729-0102', 7.1783648),
#   ('AP890719-0082', 7.175185),
#   ('AP890513-0085', 7.158638),
#   ('AP890606-0091', 7.148856),
#   ('AP890612-0157', 7.141227),
#   ('AP890430-0064', 7.133713),
#   ('AP890110-0090', 7.133713),
#   ('AP890217-0091', 7.133358),
#   ('AP890227-0192', 7.128087),
#   ('AP890702-0048', 7.128087),
#   ('AP890222-0047', 7.123851),
#   ('AP890301-0001', 7.123526),
#   ('AP890521-0026', 6.1023273),
#   ('AP890308-0130', 6.1014466),
#   ('AP890610-0018', 6.1014466),
#   ('AP891229-0134', 6.100281),
#   ('AP890503-0040', 6.096992),
#   ('AP890106-0147', 6.0962377),
#   ('AP890430-0033', 6.095529),
#   ('AP891121-0223', 6.093704),
#   ('AP890117-0146', 6.0936217),
#   ('AP890508-0166', 6.0936217),
#   ('AP891115-0034', 6.0936217),
#   ('AP890109-0214', 6.093522),
#   ('AP890515-0066', 6.093522),
#   ('AP891222-0031', 6.093436)]}

# %% [markdown]
# ### Okapi TF
# This is a vector space model using a slightly modified version of TF to score documents.

# %%
def okapi_tf(tf_wd, curr_doc_len, avg_doc_len):
    return tf_wd / (tf_wd + 0.5 + (1.5 * (curr_doc_len / avg_doc_len)))

def okapi_score(document, query):
    curr_doc_len = document_to_length[document]
    score = 0
    for term in query:
        tf_wd = get_term_freq(term, document)
        score += okapi_tf(tf_wd, curr_doc_len, average_document_length)
    return score

# %% [markdown]
# ### TF-IDF
#
# This is the second vector space model

# %%
def tf_idf_score(document_id, query):
    curr_doc_len = document_to_length[document_id]
    tf_idf_score = 0
    for word in query:
        tf_wd = get_term_freq(word, document_id)
        doc_freq = get_doc_freq(word)
        if doc_freq == 0:
            continue
        tf_idf_score += okapi_tf(tf_wd, curr_doc_len, average_document_length) * math.log(number_of_documents / doc_freq)

    return tf_idf_score

# %% [markdown]
# ### Okapi BM25
# BM25 is a language model based on a binary independence model.

# %%
def bm25_score(document_id, query):
    k1 = 1.2
    k2 = 100
    b = 0.75
    score = 0
    curr_doc_len = document_to_length[document_id]
    for word in query:
        tf_wd = get_term_freq(word, document_id)
        doc_freq = get_doc_freq(word)
        tf_wq = get_word_freq_in_query(word, query)
        
        subscore = np.log((number_of_documents + 0.5) / (doc_freq + 0.5))
        subscore *= (tf_wd + k1 * tf_wd) / (tf_wd + k1 * ((1 - b) + b * (curr_doc_len / average_document_length)))
        subscore *= (tf_wq + k2 * tf_wq) / (tf_wq + k2)
        score += subscore
        
    return score

# %% [markdown]
# ### Unigram LM with Laplace smoothing
# This is a language model with Laplace (“add-one”) smoothing. We will use maximum likelihood estimates of the query based on a multinomial model “trained” on the document.

# %%
def p_laplace(word, document, tf_wd):
    return (tf_wd + 1) / (document_to_length[document] + vocabulary_size)

def lm_laplace(document, query):
    score = 0
    for word in query:
        tf_wd = get_term_freq(word, document)
        if tf_wd == 0:
            score -= 100
        else:
            score += np.log(p_laplace(word, document, tf_wd))
    return score

# %% [markdown]
# ## Unigram LM with Jelinek-Mercer smoothing
#
# This is a similar language model, except that here we smooth a foreground document language model with a background model from the entire corpus.

# %%
def p_jm(word, document, tf_wd, lambda_jm=0.98):
    p_mle = tf_wd / document_to_length[document]
    ttf = term_total_term_frequency[word]
    return lambda_jm * p_mle + (1 - lambda_jm) * ttf / total_document_length

def lm_jm(document, query):
    score = 0
    for word in query:
        tf_wd = get_term_freq(word, document)
        if tf_wd == 0:
            score -= 100
        else:
            score += np.log(p_jm(word, document, tf_wd))
    return score

# %% [markdown]
# ## Task4: Evaluation

# %% [markdown]
# A) Compare manually the top 10 docs returned by ESBuilt-In, TFIDF, BM25, LMLaplace, for 5 queries specified by TAs. Explain or speculate on the reasons for differences in the rankings

# %%
retrieval_models = ['ES', 'OKAPI', 'TFIDF', 'BM25', 'LMLAPLACE', 'LMJM' ]

def master_score(document, query, model):
    if model == 'OKAPI':
        return okapi_score(document, query)
    elif model == 'TFIDF':
        return tf_idf_score(document, query)
    elif model == 'BM25':
        return bm25_score(document, query)
    elif model == 'LMLAPLACE':
        return lm_laplace(document, query)
    elif model == 'LMJM':
        return lm_jm(document, query)

def calculate_scores(queries, models=retrieval_models):
    scores = {}
    for model in models:
        print('Calculating scores for', model)
        if model == 'ES':
            scores[model] = es_built_in_search(queries)
        else:
            scores[model] = {}
            for query_id, query in queries.items():
                query = query['processed_query']
                scores[model][query_id] = []
                for document in all_document_ids:
                    if document_to_length[document] == 0:
                        continue
                    scores[model][query_id].append((document, master_score(document, query, model)))
    
            for query_id, query in queries.items():
                scores[model][query_id].sort(key=lambda x: x[1], reverse=True)

    return scores

scores = calculate_scores(queries)
# Out:
# Calculating scores for ES
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_64086/2650714926.py:7: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=INDEX_NAME, body={
# Calculating scores for OKAPI
# Calculating scores for TFIDF
# Calculating scores for BM25
# Calculating scores for LMLAPLACE
# Calculating scores for LMJM

# %%
for model in retrieval_models:
    with open('results_' + model + '.txt', 'w') as file:
        for query_id, query_scores in scores[model].items():
            for i, (document, score) in enumerate(query_scores):
                file.write(query_id + ' Q0 ' + document + ' ' + str(i + 1) + ' ' + str(score) + ' ' + 'Exp' + '\n')
                if i == 1000:
                    break

# %%
print("ES Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_ES.txt

print("--------------------------------------------")
print("Okapi Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_OKAPI.txt

print("--------------------------------------------")
print("TFIDF Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_TFIDF.txt

print("--------------------------------------------")
print("BM25 Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_BM25.txt

print("--------------------------------------------")
print("LMLAPLACE Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_LMLAPLACE.txt

print("--------------------------------------------")
print("LMJM Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_LMJM.txt
# Out:
# ES Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1319
# Interpolated Recall - Precision Averages:
#     at 0.00       0.7125
#     at 0.10       0.5369
#     at 0.20       0.4596
#     at 0.30       0.3748
#     at 0.40       0.3240
#     at 0.50       0.2838
#     at 0.60       0.2426
#     at 0.70       0.2161
#     at 0.80       0.1694
#     at 0.90       0.0766
#     at 1.00       0.0249
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2930
# Precision:
#   At    5 docs:   0.4480
#   At   10 docs:   0.4280
#   At   15 docs:   0.3947
#   At   20 docs:   0.3800
#   At   30 docs:   0.3627
#   At  100 docs:   0.2424
#   At  200 docs:   0.1704
#   At  500 docs:   0.0933
#   At 1000 docs:   0.0528
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.3186
# --------------------------------------------
# Okapi Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1182
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6646
#     at 0.10       0.4806
#     at 0.20       0.3602
#     at 0.30       0.2922
#     at 0.40       0.2499
#     at 0.50       0.2023
#     at 0.60       0.1580
#     at 0.70       0.1311
#     at 0.80       0.1047
#     at 0.90       0.0586
#     at 1.00       0.0087
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2290
# Precision:
#   At    5 docs:   0.4080
#   At   10 docs:   0.3880
#   At   15 docs:   0.3493
#   At   20 docs:   0.3280
#   At   30 docs:   0.3067
#   At  100 docs:   0.1980
#   At  200 docs:   0.1430
#   At  500 docs:   0.0785
#   At 1000 docs:   0.0473
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2581
# --------------------------------------------
# TFIDF Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1317
# Interpolated Recall - Precision Averages:
#     at 0.00       0.7185
#     at 0.10       0.5546
#     at 0.20       0.4371
#     at 0.30       0.3691
#     at 0.40       0.3189
#     at 0.50       0.2838
#     at 0.60       0.2414
#     at 0.70       0.2116
#     at 0.80       0.1517
#     at 0.90       0.0747
#     at 1.00       0.0221
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2907
# Precision:
#   At    5 docs:   0.4480
#   At   10 docs:   0.4200
#   At   15 docs:   0.4027
#   At   20 docs:   0.3900
#   At   30 docs:   0.3640
#   At  100 docs:   0.2408
#   At  200 docs:   0.1696
#   At  500 docs:   0.0924
#   At 1000 docs:   0.0527
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.3111
# --------------------------------------------
# BM25 Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1298
# Interpolated Recall - Precision Averages:
#     at 0.00       0.7200
#     at 0.10       0.5300
#     at 0.20       0.4295
#     at 0.30       0.3590
#     at 0.40       0.3093
#     at 0.50       0.2739
#     at 0.60       0.2288
#     at 0.70       0.2018
#     at 0.80       0.1556
#     at 0.90       0.0826
#     at 1.00       0.0251
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2809
# Precision:
#   At    5 docs:   0.4480
#   At   10 docs:   0.3920
#   At   15 docs:   0.3840
#   At   20 docs:   0.3680
#   At   30 docs:   0.3560
#   At  100 docs:   0.2348
#   At  200 docs:   0.1632
#   At  500 docs:   0.0910
#   At 1000 docs:   0.0519
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.3029
# --------------------------------------------
# LMLAPLACE Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1152
# Interpolated Recall - Precision Averages:
#     at 0.00       0.7015
#     at 0.10       0.4841
#     at 0.20       0.4260
#     at 0.30       0.3058
#     at 0.40       0.2619
#     at 0.50       0.1918
#     at 0.60       0.1473
#     at 0.70       0.1184
#     at 0.80       0.0848
#     at 0.90       0.0446
#     at 1.00       0.0108
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2316
# Precision:
#   At    5 docs:   0.4480
#   At   10 docs:   0.4000
#   At   15 docs:   0.3680
#   At   20 docs:   0.3240
#   At   30 docs:   0.2907
#   At  100 docs:   0.2104
#   At  200 docs:   0.1512
#   At  500 docs:   0.0758
#   At 1000 docs:   0.0461
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2671
# --------------------------------------------
# LMJM Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1123
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6605
#     at 0.10       0.4660
#     at 0.20       0.3667
#     at 0.30       0.2994
#     at 0.40       0.2411
#     at 0.50       0.1970
#     at 0.60       0.1498
#     at 0.70       0.1261
#     at 0.80       0.0924
#     at 0.90       0.0425
#     at 1.00       0.0165
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2191
# Precision:
#   At    5 docs:   0.3840
#   At   10 docs:   0.3400
#   At   15 docs:   0.3227
#   At   20 docs:   0.3020
#   At   30 docs:   0.2693
#   At  100 docs:   0.2032
#   At  200 docs:   0.1394
#   At  500 docs:   0.0734
#   At 1000 docs:   0.0449
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2522

# %%
def get_top_n_docs(model, query_id, n=10):
    print("The given model is: ", model)
    print(f"Query {query_id} : {queries[query_id]['processed_query']}")
    print(f"Top {n} documents are: ")

    for i in range(n):
        print(f"\tRank {i+1}. {scores[model][query_id][i][0]} with score {scores[model][query_id][i][1]}")
        # get the document
        doc = es.get(index=INDEX_NAME, id=scores[model][query_id][i][0])
        print(doc['_source']['content'])

# %%
for model in retrieval_models:
    get_top_n_docs(model, '85')
# Out:
# The given model is:  ES
# Query 85 : ['alleg', 'corrupt', 'public', 'offici']
# Top 10 documents are:
# 	Rank 1. AP890220-0143 with score 14.12233
# bomb explod offic interior justic minist enriqu ortez colindr monday order polic occup prison offici accus corrupt injuri report four stick dynamit explod 7 10 p m damag build shatter window honduran telecommun co build street polic sourc immedi claim responsibl polic sunday occupi nation s largest prison govern accus prison offici corrupt drug traffick tri foment riot 1 500 inmat offici monday public secur forc statement detect danger escal sedit riot occur today monday alleg particip offici central penitentiari tegucigalpa capit prison offici highli danger delinqu plan riot massiv escap prison detriment nation secur tranquil ortez colindr told associ press temporarili suspend prison director marco tulio mendieta ortez colindr name maj david mendoza garcia school prison administr argentina facil s act director polic statement investig detect elev proven administr corrupt traffick drug sale exit permit danger crimin incit arm revolt guard indiscrimin possess arm prison irregular 200 member crack cobra polic squadron occupi facil late sunday ensur public order 60 prison guard offici arrest offici takeov peac report casualti central penitentiari hous inmat convict violent crime homicid rape drug traffick
# 	Rank 2. AP890108-0030 with score 14.116497
# three former drug agent accus deal cocain money launder possibl seduc glamor hollywood lifestyl larg sum money made southern california s grow drug trade offici alleg conspiraci three men part 150 agent drug enforc administr conting assign lo angel area worri offici case multipl agent corrupt rare appar isol despit increas temptat region assist u s attorney joyc karlin three bad appl forc embarrass karlin offer dea agent ve work 1 million 10 million sell laugh face probe alleg corrupt trio agent charg tax evas widen alleg heroin cash theft dea vault cocain traffick karlin former agent john jackson darnel garcia wayn countryman indict tax fraud alleg conspiraci launder 608 000 swiss bank face new charg cocain traffick end januari karlin offici given detail men accus intern revenu servic agent john anderson evid three involv money launder narcot traffick follow employ three left drug agenc indict hand defens lawyer dea u s attorney s offic smear client condemn leak news media alleg racism investig agent black attorney three declin request interview associ press west coast scandal uncov intern agenc review came beef dea south florida led drug smuggler southern california altern point entri high cost live frustrat increas work pressur gambl allur hollywood lifestyl blame possibl caus alleg corrupt peopl disgruntl system disgruntl work burn karlin prosecut case alleg tax evas conspiraci began 1984 alleg wrongdo occur period west coast experienc influx drug smuggl s glitzi l lifestyl miami attract corrupt _ thing abund merced jaguar bmw pricey shop fanci restaur luxuri home averag dea agent earn 30 000 40 000 karlin case signific involv alleg three agent work jackson 39 held bail deem risk flee pressur wit case karlin countryman 45 freed 120 000 bail garcia 42 elud agent follow hour plan arrest remain fugit jackson countryman plead guilti arraign u s district court dec 19 three indict agent investig connect disappear heroin cash dea vault late 1984 earli 1985 offic spokesman agent ralph lochridg john zeinter dea agent charg lo angel offic refus reveal heroin cash miss addit charg file feder prosecutor publish report five pound heroin worth estim 7 5 million nearli 100 000 cash vanish least three separ theft agencywid figur past corrupt convict dea agent unavail dea spokesman bill deac lo angel agent convict drug case georg hoelker found guilti five year ago conspir sell five pound cocain gerald caiden professor univers southern california special law enforc corrupt problem grow nationwid case symptomat wider corrupt gener declin public moral 30 year _ goe long don t caught caiden three agent told colleagu busi endeavor ban dea lochridg exampl jackson reportedli explain merced benz sport car heavi gambl loss night poker game say money made oper amway franchis
# %% [markdown]
# # Task5: Pseudo-relevance Feedback (MS students only)
# Pseudo-relevance Feedback
# Implement pseudo-relevance feedback. The general algorithm is:
#
# - Retrieve the top k documents using one of the above retrieval models.
# - Identify terms in these documents which are distinctive to the documents.
# - Add the terms to the query, and re-run the retrieval process. Return the final results.
# - It is up to you to devise a reasonable way to choose terms to add to the query. It doesn’t have to be complicated, but you should be prepared to explain and justify your approach.
#
# Evaluate your results using trec_eval and include similar metrics with your submission.

# %%
def get_top_n_terms(document_id, n=10):
    # calculate the tfidf to get the distinctive terms
    tfidf = {}
    for term in document_to_vectors[document_id]:
        tf = get_term_freq(term, document_id)
        idf = math.log(number_of_documents / get_doc_freq(term))
        tfidf[term] = tf * idf
    return sorted(tfidf.items(), key=lambda x: x[1], reverse=True)[:n]
    
def pseudo_relevance_feedback(model, k=5, n=1):
    print('Running pseudo relevance feedback for', model)
    new_queries = {}
    for query_id, query in queries.items():
        query = query['processed_query']
        top_k_docs = [x[0] for x in scores[model][query_id][:k]]
        new_query = query.copy()
        for doc in top_k_docs:
            doc_terms = document_to_vectors[doc]
            for i, term in enumerate(doc_terms):
                # Get the top n terms from the document
                top_n_terms = get_top_n_terms(doc, n)
                for term in top_n_terms:
                    if term[0] not in new_query:
                        new_query.append(term[0])
        new_queries[query_id] = {"processed_query" : new_query}
    return new_queries


retrieval_models = ['ES', 'OKAPI', 'TFIDF', 'BM25', 'LMLAPLACE', 'LMJM' ]


new_queries_pr = pseudo_relevance_feedback('OKAPI')
new_scores_pr = calculate_scores(new_queries_pr, retrieval_models)

for model in retrieval_models:
    new_queries_pr[model] = pseudo_relevance_feedback(model)
    new_scores_pr[model] = calculate_scores(new_queries_pr[model], [model])
    with open('results_relevance_' + model + '.txt', 'w') as file:
        for query_id, query_scores in new_scores_pr[model][model].items():
            for i, (document, score) in enumerate(query_scores):
                file.write(query_id + ' Q0 ' + document + ' ' + str(i + 1) + ' ' + str(score) + ' ' + 'Exp' + '\n')
                if i == 1000:
                    break
# Out:
# Running pseudo relevance feedback for OKAPI
# Calculating scores for ES
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_64086/2650714926.py:7: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=INDEX_NAME, body={
# Calculating scores for OKAPI
# Calculating scores for TFIDF
# Calculating scores for BM25
# Calculating scores for LMLAPLACE
# Calculating scores for LMJM
# Running pseudo relevance feedback for ES
# Calculating scores for ES
# Running pseudo relevance feedback for OKAPI
# Calculating scores for OKAPI
# Running pseudo relevance feedback for TFIDF
# Calculating scores for TFIDF
# Running pseudo relevance feedback for BM25
# Calculating scores for BM25
# Running pseudo relevance feedback for LMLAPLACE
# Calculating scores for LMLAPLACE
# Running pseudo relevance feedback for LMJM
# Calculating scores for LMJM

# %%
print("ES Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_ES.txt

print("--------------------------------------------")
print("Okapi Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_OKAPI.txt

print("--------------------------------------------")
print("TFIDF Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_TFIDF.txt

print("--------------------------------------------")
print("BM25 Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_BM25.txt

print("--------------------------------------------")
print("LMLAPLACE Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_LMLAPLACE.txt

print("--------------------------------------------")
print("LMJM Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_LMJM.txt
# Out:
# ES Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1335
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6593
#     at 0.10       0.5203
#     at 0.20       0.3784
#     at 0.30       0.3270
#     at 0.40       0.2968
#     at 0.50       0.2527
#     at 0.60       0.2136
#     at 0.70       0.1834
#     at 0.80       0.1438
#     at 0.90       0.0643
#     at 1.00       0.0170
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2618
# Precision:
#   At    5 docs:   0.3920
#   At   10 docs:   0.3800
#   At   15 docs:   0.3520
#   At   20 docs:   0.3180
#   At   30 docs:   0.3067
#   At  100 docs:   0.2212
#   At  200 docs:   0.1562
#   At  500 docs:   0.0886
#   At 1000 docs:   0.0534
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2826
# --------------------------------------------
# Okapi Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1219
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6530
#     at 0.10       0.4997
#     at 0.20       0.3539
#     at 0.30       0.3193
#     at 0.40       0.2698
#     at 0.50       0.2184
#     at 0.60       0.1789
#     at 0.70       0.1221
#     at 0.80       0.0906
#     at 0.90       0.0506
#     at 1.00       0.0076
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2326
# Precision:
#   At    5 docs:   0.3760
#   At   10 docs:   0.3480
#   At   15 docs:   0.3440
#   At   20 docs:   0.3400
#   At   30 docs:   0.3093
#   At  100 docs:   0.2128
#   At  200 docs:   0.1496
#   At  500 docs:   0.0808
#   At 1000 docs:   0.0488
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2606
# --------------------------------------------
# TFIDF Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1337
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6158
#     at 0.10       0.5067
#     at 0.20       0.3643
#     at 0.30       0.3176
#     at 0.40       0.2945
#     at 0.50       0.2573
#     at 0.60       0.2148
#     at 0.70       0.1779
#     at 0.80       0.1257
#     at 0.90       0.0547
#     at 1.00       0.0148
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2520
# Precision:
#   At    5 docs:   0.4000
#   At   10 docs:   0.3640
#   At   15 docs:   0.3520
#   At   20 docs:   0.3180
#   At   30 docs:   0.3040
#   At  100 docs:   0.2204
#   At  200 docs:   0.1552
#   At  500 docs:   0.0886
#   At 1000 docs:   0.0535
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2804
# --------------------------------------------
# BM25 Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1321
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6559
#     at 0.10       0.5177
#     at 0.20       0.3702
#     at 0.30       0.3244
#     at 0.40       0.2947
#     at 0.50       0.2495
#     at 0.60       0.2071
#     at 0.70       0.1718
#     at 0.80       0.1337
#     at 0.90       0.0626
#     at 1.00       0.0170
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2561
# Precision:
#   At    5 docs:   0.3920
#   At   10 docs:   0.3680
#   At   15 docs:   0.3493
#   At   20 docs:   0.3120
#   At   30 docs:   0.3000
#   At  100 docs:   0.2192
#   At  200 docs:   0.1540
#   At  500 docs:   0.0878
#   At 1000 docs:   0.0528
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2749
# --------------------------------------------
# LMLAPLACE Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1182
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6571
#     at 0.10       0.5385
#     at 0.20       0.4036
#     at 0.30       0.3362
#     at 0.40       0.2677
#     at 0.50       0.2043
#     at 0.60       0.1731
#     at 0.70       0.1211
#     at 0.80       0.0886
#     at 0.90       0.0402
#     at 1.00       0.0085
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2441
# Precision:
#   At    5 docs:   0.4880
#   At   10 docs:   0.4120
#   At   15 docs:   0.3787
#   At   20 docs:   0.3500
#   At   30 docs:   0.3253
#   At  100 docs:   0.2224
#   At  200 docs:   0.1514
#   At  500 docs:   0.0807
#   At 1000 docs:   0.0473
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2663
# --------------------------------------------
# LMJM Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1154
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6828
#     at 0.10       0.5254
#     at 0.20       0.3599
#     at 0.30       0.3295
#     at 0.40       0.2706
#     at 0.50       0.2034
#     at 0.60       0.1707
#     at 0.70       0.1227
#     at 0.80       0.0950
#     at 0.90       0.0421
#     at 1.00       0.0169
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2393
# Precision:
#   At    5 docs:   0.4400
#   At   10 docs:   0.4000
#   At   15 docs:   0.3467
#   At   20 docs:   0.3380
#   At   30 docs:   0.3067
#   At  100 docs:   0.2192
#   At  200 docs:   0.1474
#   At  500 docs:   0.0804
#   At 1000 docs:   0.0462
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2758

# %% [markdown]
# ## Pseudo-relevance Feedback using ElasticSearch aggs "significant terms"
# Use ES API "significat terms" separately on each query term (stem root) to get a list of related words. The words you want to add to the query are:
#     - related to more than one query term
#     - not stopwords
#     - high IDF
#     - other tricks you might need in order to only get interesting words
# Add few of these words to the query and rerun your models.
#
# Below is an example of this API in Sense for query term "atom":
# GET /ap_dataset/document/_search
# {
#     "query" : {
#         "terms" : {"TEXT" : [ "atom" ]}
#     },
#     "aggregations" : {
#         "significantCrimeTypes" : {
#             "significant_terms" : {
#               "field" : "TEXT"
#             }
#         }
#     },
#     "size": 0
# }

# %%
def get_significant_terms(term):
#     - related to more than one query term
#     - not stopwords
#     - high IDF
#     - other tricks you might need in order to only get interesting words
    res = es.search(index=INDEX_NAME, body={
        "query" : {
            "terms" : {"content" : [ term ]}
        },
        "aggregations" : {
            "significantCrimeTypes" : {
                "significant_terms" : {
                  "field" : "content"             
                }
            }
        },
        "size": 0
    })
    return res['aggregations']['significantCrimeTypes']['buckets']

def get_all_related_terms(query, n=5):
    related_terms = []
    for term in query:
        related_terms.extend(get_significant_terms(term))
    # Sort realted terms by score
    related_terms = sorted(related_terms, key=lambda x: x['score'], reverse=True)
    related_terms = [x for x in related_terms if x['key'] not in query]
    # add idf and sort by idf
    for term in related_terms:
        term['idf'] = math.log(number_of_documents / get_doc_freq(term['key']))
    related_terms = sorted(related_terms, key=lambda x: x['idf'], reverse=True)

    return related_terms[:n]

def pseudo_relevance_feedback_es(queries, n=3):
    new_queries = {}
    for query_id, query in queries.items():
        query = query['processed_query']
        new_query = query.copy()
        related_terms = get_all_related_terms(query, n)
        for term in related_terms:
            new_query.append(term['key'])
        new_queries[query_id] = {"processed_query" : new_query}
    return new_queries

new_queries_es = pseudo_relevance_feedback_es(queries)
new_scores_es = calculate_scores(new_queries_es, retrieval_models)

for model in retrieval_models:
    with open('results_relevance_es_aggs_' + model + '.txt', 'w') as file:
        for query_id, query_scores in new_scores_es[model].items():
            for i, (document, score) in enumerate(query_scores):
                file.write(query_id + ' Q0 ' + document + ' ' + str(i + 1) + ' ' + str(score) + ' ' + 'Exp' + '\n')
                if i == 1000:
                    break
# Out:
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_64086/780878633.py:34: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=INDEX_NAME, body={
# Calculating scores for ES
# /var/folders/cg/pnd4sxn93218rhbf3zhwszv00000gn/T/ipykernel_64086/2650714926.py:7: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res = es.search(index=INDEX_NAME, body={
# Calculating scores for OKAPI
# Calculating scores for TFIDF
# Calculating scores for BM25
# Calculating scores for LMLAPLACE
# Calculating scores for LMJM

# %%
print("ES Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_ES.txt

print("--------------------------------------------")
print("Okapi Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_OKAPI.txt

print("--------------------------------------------")
print("TFIDF Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_TFIDF.txt

print("--------------------------------------------")
print("BM25 Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_BM25.txt

print("--------------------------------------------")
print("LMLAPLACE Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_LMLAPLACE.txt

print("--------------------------------------------")
print("LMJM Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_relevance_es_aggs_LMJM.txt
# Out:
# ES Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1314
# Interpolated Recall - Precision Averages:
#     at 0.00       0.4991
#     at 0.10       0.4097
#     at 0.20       0.3649
#     at 0.30       0.3166
#     at 0.40       0.2764
#     at 0.50       0.2387
#     at 0.60       0.1985
#     at 0.70       0.1749
#     at 0.80       0.1354
#     at 0.90       0.0714
#     at 1.00       0.0235
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2284
# Precision:
#   At    5 docs:   0.3120
#   At   10 docs:   0.3240
#   At   15 docs:   0.3253
#   At   20 docs:   0.3140
#   At   30 docs:   0.3053
#   At  100 docs:   0.1964
#   At  200 docs:   0.1376
#   At  500 docs:   0.0854
#   At 1000 docs:   0.0526
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2447
# --------------------------------------------
# Okapi Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1225
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6500
#     at 0.10       0.4739
#     at 0.20       0.3703
#     at 0.30       0.3230
#     at 0.40       0.2697
#     at 0.50       0.2075
#     at 0.60       0.1629
#     at 0.70       0.1338
#     at 0.80       0.1026
#     at 0.90       0.0617
#     at 1.00       0.0084
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2348
# Precision:
#   At    5 docs:   0.4080
#   At   10 docs:   0.3960
#   At   15 docs:   0.3440
#   At   20 docs:   0.3300
#   At   30 docs:   0.3107
#   At  100 docs:   0.2044
#   At  200 docs:   0.1452
#   At  500 docs:   0.0814
#   At 1000 docs:   0.0490
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2655
# --------------------------------------------
# TFIDF Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1313
# Interpolated Recall - Precision Averages:
#     at 0.00       0.5188
#     at 0.10       0.4073
#     at 0.20       0.3684
#     at 0.30       0.3379
#     at 0.40       0.2859
#     at 0.50       0.2442
#     at 0.60       0.2032
#     at 0.70       0.1788
#     at 0.80       0.1297
#     at 0.90       0.0699
#     at 1.00       0.0208
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2331
# Precision:
#   At    5 docs:   0.3360
#   At   10 docs:   0.3200
#   At   15 docs:   0.3253
#   At   20 docs:   0.3180
#   At   30 docs:   0.3067
#   At  100 docs:   0.1948
#   At  200 docs:   0.1386
#   At  500 docs:   0.0839
#   At 1000 docs:   0.0525
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2472
# --------------------------------------------
# BM25 Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1293
# Interpolated Recall - Precision Averages:
#     at 0.00       0.4938
#     at 0.10       0.4047
#     at 0.20       0.3600
#     at 0.30       0.3283
#     at 0.40       0.2775
#     at 0.50       0.2364
#     at 0.60       0.1943
#     at 0.70       0.1697
#     at 0.80       0.1310
#     at 0.90       0.0783
#     at 1.00       0.0237
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2276
# Precision:
#   At    5 docs:   0.3280
#   At   10 docs:   0.3320
#   At   15 docs:   0.3173
#   At   20 docs:   0.3160
#   At   30 docs:   0.3053
#   At  100 docs:   0.1948
#   At  200 docs:   0.1344
#   At  500 docs:   0.0834
#   At 1000 docs:   0.0517
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2476
# --------------------------------------------
# LMLAPLACE Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1213
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6089
#     at 0.10       0.4418
#     at 0.20       0.4021
#     at 0.30       0.3210
#     at 0.40       0.2482
#     at 0.50       0.1988
#     at 0.60       0.1597
#     at 0.70       0.1155
#     at 0.80       0.0851
#     at 0.90       0.0416
#     at 1.00       0.0098
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2238
# Precision:
#   At    5 docs:   0.4240
#   At   10 docs:   0.3800
#   At   15 docs:   0.3680
#   At   20 docs:   0.3440
#   At   30 docs:   0.3120
#   At  100 docs:   0.2116
#   At  200 docs:   0.1482
#   At  500 docs:   0.0812
#   At 1000 docs:   0.0485
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2688
# --------------------------------------------
# LMJM Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:       1196
# Interpolated Recall - Precision Averages:
#     at 0.00       0.6306
#     at 0.10       0.4373
#     at 0.20       0.3844
#     at 0.30       0.3109
#     at 0.40       0.2333
#     at 0.50       0.1903
#     at 0.60       0.1611
#     at 0.70       0.1237
#     at 0.80       0.1007
#     at 0.90       0.0450
#     at 1.00       0.0158
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.2208
# Precision:
#   At    5 docs:   0.4000
#   At   10 docs:   0.3680
#   At   15 docs:   0.3413
#   At   20 docs:   0.3320
#   At   30 docs:   0.3107
#   At  100 docs:   0.2012
#   At  200 docs:   0.1454
#   At  500 docs:   0.0794
#   At 1000 docs:   0.0478
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.2628

# %%
for query in queries:
    print("ID: ", query)
    print("Query : ", queries[query]['original_query'])
    print("Processed Query: ", " ".join(queries[query]['processed_query']))
    print("New Query using pseudo relevance: ", " ".join(new_queries_pr[query]['processed_query']))
    print("New Query using pseudo relevance with ES aggs: ", " ".join(new_queries_es[query]['processed_query']))
    print("=============================================")
# Out:
# ID:  85
# Query :     Document will discuss allegations, or measures being taken against, corrupt public officials of any governmental jurisdiction worldwide.
#
# Processed Query:  alleg corrupt public offici
# New Query using pseudo relevance:  alleg corrupt public offici ortez ligachev connaughton
# New Query using pseudo relevance with ES aggs:  alleg corrupt public offici ziyang zhao xiaop
# =============================================
# ID:  59
# Query :     Document will report a type of weather event which has directly caused at least one fatality in some location.
#
# Processed Query:  weather least fatal locat
# New Query using pseudo relevance:  weather least fatal locat thunderstorm tornado connel
# New Query using pseudo relevance with ES aggs:  weather least fatal locat overtown longitud thunderstorm
# =============================================
# ID:  56
# Query :     Document will include a prediction about the prime lending rate, or will report an actual prime rate move.
#
# Processed Query:  prime lend rate prime rate
# New Query using pseudo relevance:  prime lend rate prime rate bank
# New Query using pseudo relevance with ES aggs:  prime lend rate prime rate 0550 0102 minskoff
# =============================================
# ID:  71
# Query :     Document will report incursions by land, air, or water into the border area of one country by military forces of a second country or a guerrilla group based in a second country.
#
# Processed Query:  incurs border area militari forc second guerrilla second
# New Query using pseudo relevance:  incurs border area militari forc second guerrilla second dinghi jalalabad namibia contra
# New Query using pseudo relevance with ES aggs:  incurs border area militari forc second guerrilla second thornberri cedric ahtisaari
# =============================================
# ID:  64
# Query :     Document will report an event or result of politically motivated hostage-taking.
#
# Processed Query:  result polit hostag take
# New Query using pseudo relevance:  result polit hostag take q schramm
# New Query using pseudo relevance with ES aggs:  result polit hostag take obeid captor hezbollah
# =============================================
# ID:  62
# Query :     Document will report a military coup d'etat, either attempted or successful, in any country.
#
# Processed Query:  militari coup d etat attempt
# New Query using pseudo relevance:  militari coup d etat attempt haitian skelton boren noriega cerezo
# New Query using pseudo relevance with ES aggs:  militari coup d etat attempt thinli stroessner pinochet
# =============================================
# ID:  93
# Query :     Document must describe or identify supporters of the National Rifle Association (NRA), or its assets.
#
# Processed Query:  support nation rifl associ nra
# New Query using pseudo relevance:  support nation rifl associ nra behan
# New Query using pseudo relevance with ES aggs:  support nation rifl associ nra ar15 lapierr carbin
# =============================================
# ID:  99
# Query :     Document will identify a development in the Iran-Contra Affair.
#
# Processed Query:  develop iran contra affair
# New Query using pseudo relevance:  develop iran contra affair mees fernandez document
# New Query using pseudo relevance with ES aggs:  develop iran contra affair gesel rafsanjani hud
# =============================================
# ID:  58
# Query :     Document will predict or anticipate a rail strike or report an ongoing rail  strike.
#
# Processed Query:  rail strike ongo rail strike
# New Query using pseudo relevance:  rail strike ongo rail strike
# New Query using pseudo relevance with ES aggs:  rail strike ongo rail strike limpi noid oi
# =============================================
# ID:  77
# Query :     Document will report a poaching method used against a certain type of wildlife.
#
# Processed Query:  poach method wildlif
# New Query using pseudo relevance:  poach method wildlif gator leakey eleph
# New Query using pseudo relevance with ES aggs:  poach method wildlif shifta lifo bont
# =============================================
# ID:  54
# Query :     Document will cite the signing of a contract or preliminary agreement, or the making of a tentative reservation, to launch a commercial satellite.
#
# Processed Query:  contract agreement reserv launch commerci satellit
# New Query using pseudo relevance:  contract agreement reserv launch commerci satellit marcopolo nasa titan
# New Query using pseudo relevance with ES aggs:  contract agreement reserv launch commerci satellit blaha holliston payload
# =============================================
# ID:  87
# Query :     Document will report on current criminal actions against officers of a failed U.S. financial institution.
#
# Processed Query:  current offic fail u s institut
# New Query using pseudo relevance:  current offic fail u s institut noriega copyright technolog panel gildemeist
# New Query using pseudo relevance with ES aggs:  current offic fail u s institut comex insolv ls
# =============================================
# ID:  94
# Query :     Document must identify a crime perpetrated with the aid of a computer.
#
# Processed Query:  crime aid comput
# New Query using pseudo relevance:  crime aid comput disk brennan fetter
# New Query using pseudo relevance with ES aggs:  crime aid comput compaq semiconductor softwar
# =============================================
# ID:  100
# Query :    Document will identify efforts by the non-communist, industrialized states to regulate the transfer of high-tech goods or "dual-use" technologies to undesirable nations.
#
# Processed Query:  non communist state transfer high tech good technolog nation
# New Query using pseudo relevance:  non communist state transfer high tech good technolog nation freedenberg mosbach aucoin
# New Query using pseudo relevance with ES aggs:  non communist state transfer high tech good technolog nation voc clg sjaardema
# =============================================
# ID:  89
# Query :     Document must identify an existing or pending investment by an OPEC member state in any "downstream" operation.
#
# Processed Query:  invest opec downstream
# New Query using pseudo relevance:  invest opec downstream oapec aqazadeh gelb
# New Query using pseudo relevance with ES aggs:  invest opec downstream marlar coahoma hoffbauer
# =============================================
# ID:  61
# Query :     Document will discuss the role of Israel in the Iran-Contra Affair.
#
# Processed Query:  israel iran contra affair
# New Query using pseudo relevance:  israel iran contra affair mees notebook
# New Query using pseudo relevance with ES aggs:  israel iran contra affair gesel rafsanjani ortega
# =============================================
# ID:  95
# Query :     Document must describe a computer application to crime solving.
#
# Processed Query:  comput applic crime
# New Query using pseudo relevance:  comput applic crime nagao shapiro ncic
# New Query using pseudo relevance with ES aggs:  comput applic crime harlingen compaq semiconductor
# =============================================
# ID:  68
# Query :     Document will report actual studies, or even unsubstantiated concerns about the safety to manufacturing employees and installation workers of fine-diameter fibers used in insulation and other products.
#
# Processed Query:  concern safeti manufactur worker fine diamet fiber product
# New Query using pseudo relevance:  concern safeti manufactur worker fine diamet fiber product asbesto nissan osha fasten
# New Query using pseudo relevance with ES aggs:  concern safeti manufactur worker fine diamet fiber product n2 14159 chudnovski
# =============================================
# ID:  57
# Query :     Document will discuss how MCI has been doing since the Bell System breakup.
#
# Processed Query:  mci bell system
# New Query using pseudo relevance:  mci bell system creech fcc electron bellcor
# New Query using pseudo relevance with ES aggs:  mci bell system dicicco tutton mitnick
# =============================================
# ID:  97
# Query :     Document must identify instances of fiber optics technology actually in use.
#
# Processed Query:  fiber optic technolog
# New Query using pseudo relevance:  fiber optic technolog lightnet heyman cabl
# New Query using pseudo relevance with ES aggs:  fiber optic technolog resolidifi indium telekom
# =============================================
# ID:  98
# Query :     Document must identify individuals or organizations which produce fiber optics equipment.
#
# Processed Query:  fiber optic equip
# New Query using pseudo relevance:  fiber optic equip pco cabl lightnet satellit
# New Query using pseudo relevance with ES aggs:  fiber optic equip resolidifi indium telekom
# =============================================
# ID:  60
# Query :     Document will describe either one or both sides of the controversy over the use of standards of performance to determine salary levels and incentive pay as contrasted with determining pay solely on the basis of seniority or longevity on the job.
#
# Processed Query:  perform salari incent pay pay
# New Query using pseudo relevance:  perform salari incent pay pay mcnutt nader
# New Query using pseudo relevance with ES aggs:  perform salari incent pay pay showroom rebat honoraria
# =============================================
# ID:  80
# Query :     Document will identify something about the platform of a 1988 presidential  candidate.
#
# Processed Query:  1988 presidenti candid
# New Query using pseudo relevance:  1988 presidenti candid fec iowa fund buren endara
# New Query using pseudo relevance with ES aggs:  1988 presidenti candid dukaki ballot fitzwat
# =============================================
# ID:  63
# Query :     Document will identify a machine translation system.
#
# Processed Query:  machin translat system
# New Query using pseudo relevance:  machin translat system mcconnel supercomput digit vax ibm
# New Query using pseudo relevance with ES aggs:  machin translat system rozovskaya gita bourgoi
# =============================================
# ID:  91
# Query :     Document will identify acquisition by the U.S. Army of specified advanced weapons systems.
# Processed Query:  u s weapon system
# New Query using pseudo relevance:  u s weapon system tritium missil karpov
# New Query using pseudo relevance with ES aggs:  u s weapon system warhead arsen nato
# =============================================

# %% [markdown]
# # Task EC

# %%
def calculate_scores_bg(queries, models):
    scores = {}
    for model in models:
        print('Calculating scores for', model)
        if model == 'ES':
            scores[model] = es_built_in_search(queries)
        else:
            scores[model] = {}
            for query_id, query_data in tqdm(queries.items(), desc="Processing queries for model " + model):
                query = query_data['processed_query']
                scores[model][query_id] = []
                for document in all_document_ids:
                    if document_to_length[document] == 0:
                        continue
                    if model == 'BIGRAM':
                        score = bigram_score(document, ' '.join(query))
                    if score is not None:  
                        scores[model][query_id].append((document, score))
    
            for query_id, query in queries.items():
                scores[model][query_id].sort(key=lambda x: x[1], reverse=True)

    return scores

def get_bigrams(text):
    words = text.split()
    return [words[i] + ' ' + words[i + 1] for i in range(len(words) - 1)]

def bigram_score(document, query):
    doc_terms = document_to_vectors[document]
    query_bigrams = get_bigrams(query)
    
    score = 0
    if not query_bigrams:
        return 0
    
    for bigram in query_bigrams:
        term1, term2 = bigram.split()
        if term1 in doc_terms and term2 in doc_terms:
            term1_positions = [pos for pos, term in enumerate(doc_terms.keys()) if term == term1]
            term2_positions = [pos for pos, term in enumerate(doc_terms.keys()) if term == term2]
            distances = [abs(pos2 - pos1) for pos1 in term1_positions for pos2 in term2_positions]
            if distances:
                score += sum([1 / (1 + d) for d in distances])
    return score


# Example usage:
scores = calculate_scores_bg(queries,  ['BIGRAM'])

with open('results_BIGRAM' + '.txt', 'w') as file:
    for query_id, query_scores in scores['BIGRAM'].items():
        for i, (document, score) in enumerate(query_scores):
            file.write(query_id + ' Q0 ' + document + ' ' + str(i + 1) + ' ' + str(score) + ' ' + 'Exp' + '\n')
            if i == 1000:
                break

print("--------------------------------------------")
print("Bigram Retrieval Model")
# !perl ./trec_eval/trec_eval.pl AP_DATA/qrels.adhoc.51-100.AP89.txt results_BIGRAM.txt
# Out:
# Calculating scores for BIGRAM
# Processing queries for model BIGRAM: 100%|██████████| 25/25 [00:49<00:00,  1.96s/it]
# --------------------------------------------
# Bigram Retrieval Model
# Error due to 25
#
# Queryid (Num):       25
# Total number of documents over all queries
#     Retrieved:    25000
#     Relevant:      1832
#     Rel_ret:        797
# Interpolated Recall - Precision Averages:
#     at 0.00       0.3251
#     at 0.10       0.1895
#     at 0.20       0.1172
#     at 0.30       0.0915
#     at 0.40       0.0744
#     at 0.50       0.0630
#     at 0.60       0.0611
#     at 0.70       0.0523
#     at 0.80       0.0472
#     at 0.90       0.0291
#     at 1.00       0.0087
# Average precision (non-interpolated) for all rel docs(averaged over queries)
#                   0.0797
# Precision:
#   At    5 docs:   0.1680
#   At   10 docs:   0.1240
#   At   15 docs:   0.1040
#   At   20 docs:   0.1060
#   At   30 docs:   0.0960
#   At  100 docs:   0.0672
#   At  200 docs:   0.0572
#   At  500 docs:   0.0398
#   At 1000 docs:   0.0319
# R-Precision (precision after R (= num_rel for a query) docs retrieved):
#     Exact:        0.0971
